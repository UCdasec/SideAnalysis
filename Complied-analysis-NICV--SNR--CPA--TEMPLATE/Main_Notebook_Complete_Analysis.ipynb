# %% [markdown]
# # Packages : NO CHANGE REQ

# %%
import os, sys
from math import sqrt, isnan
import matplotlib.pyplot as plt
# setting the utilities required for loading the data
sys.path.append('utilities/')
from loadDataUtility import *
from graphGenerationUtilities import *
import pandas as pd
import numpy as np

# %% [markdown]
# # DATA INPUT
# Input the corresponding file path, target byte,number of traces (recomended max avaiable in npz) and attack window.
# Corresponding Values:
# Xmega: 1800_2800
# STM32F : 1200_2200

# %%
data_params = {
    "input_path": '/home/mabon/Tiny_power/datasets/power/stm32_unmasked/S1_K1_200k.npz', # path to the input file
    "target_byte": 2, # byte on which analysis is to be performed
    "start_idx": 1700, # These values depend on the architecture being tested
    "end_idx": 1900,
    "n": 50000, # This value should be equivalent to the number of power traces in the input file
    # path to save csv file containing time and nicv value (IGNORE THIS)
    "path_to_save_nicv":"result/",
    "figure_output_path": " ",
    "result_output_path": " "
}

# %% [markdown]
# # Enter path to save plots

# %%
pltpath='tempoutput/'

# %%
data_params2=data_params
# The directory to save the files is created.( This is a temp dump do not worry about this )
model_dir_path = data_params["path_to_save_nicv"]
if not os.path.isdir(model_dir_path):
    os.makedirs(model_dir_path)

# %%
# %run "notebookutility/nicv.ipynb" -data_params -pltpath

# %%
# %run "notebookutility/snr.ipynb" -data_params2 -data_params2 -pltpath

# %%
# %run "notebookutility/cpa.ipynb" -data_params2

# %% [markdown]
# # For Template Attacks

# %%
## Parameters for Sum of Difference graph
data_params3 = {
    "Training_dataset": '/home/mabon/Tiny_power/datasets/power/stm32_unmasked/S1_K1_200k.npz', # path to template input file
    "Training_traces": 50000,
    "numPOIs": 10,
    "POIspacing": 1,
    "atk_input_path": '/home/mabon/Tiny_power/datasets/power/stm32_unmasked/S1_K1_200k.npz', #path to attack input file
    "atk_n": 200,
    "target_byte": 2, # byte on which analysis is to be performed
    "attack_rounds": 15,
    "multi_plotter": True
}

# %%
# %run "notebookutility/templete_attack-randomized-runs.ipynb" -data_params3
# Out:
# POIs: [1809, 1805, 1806, 1810, 2229, 1807, 1811, 2230, 2233, 1812]
# notebookutility/templete_attack-randomized-runs.ipynb:5: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   "execution_count": null,
#   0%|          | 0/9 [00:00<?, ?it/s]
# Templete Built
# atk_input_path: /home/mabon/Tiny_power/datasets/power/stm32_unmasked/S1_K1_200k.npz
# Attack Start
# atkKey: [ 43 126  21  22  40 174 210 166 171 247  21 136   9 207  79  60]
# notebookutility/templete_attack-randomized-runs.ipynb:6: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   "id": "dde1b776",
#   0%|          | 0/15 [00:00<?, ?it/s]
